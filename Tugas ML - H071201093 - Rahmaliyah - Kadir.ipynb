# %% [markdown]
# #Tugas Mechine Learning

# %% [markdown]
# #1. API Kaggle

# %% [markdown]
# ![WhatsApp Image 2022-10-06 at 20.27.10.jpeg](data:image/jpeg;base64,...)

# %%
#Install modul kaggle
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-68db6548-9f99-4550-980c-272c2d0ca096" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68db6548-9f99-4550-980c-272c2d0ca096">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -lha kaggle.json
# Out:
# ls: cannot access 'kaggle.json': No such file or directory

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
# !kaggle datasets list -s Iris
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 166, in authenticate
#     self.config_file, self.config_dir))
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
# !kaggle datasets download uciml/iris --unzip
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 166, in authenticate
#     self.config_file, self.config_dir))
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %% [markdown]
# #2. LIBRARY PANDAS dan NUMPY

# %% [markdown]
# Pada materi ini, peserta sudah mendapatkan pemahaman mengenai data dan dataset. Penggunaan library pada Python memberikan kemudahan dalam proses data understanding. Beberapa library yang digunakan adalah library Pandas dan Numpy.

# %%
#Import Library Pandas
import pandas as pd

#Import Library Numpy
import numpy as np

# %% [markdown]
# #3. DATAFRAME

# %% [markdown]
# Panggil file (load dataset) dengan format .csv untuk dataset mengenai bunga Iris yang sudah peserta unduh dari Kaggle, dan akan disimpan di dalam dataframe df. Lalu tampilkan 5 baris awal dataset dengan function head()

# %%
#Panggil file (load file bernama Iris.csv) dan simpan dalam dataframe Lalu tampilkan 5 baris awal dataset dengan function head()
df = pd.read_csv("/content/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# DataFrame adalah struktur data 2 dimensi yang berbentuk tabular (mempunyai baris dan kolom). Hampir semua data tidak hanya memiliki 1 kolom tetapi lebih dari 1 kolom, sehingga lebih cocok menggunakan pandas DataFrame untuk mengolahnya.
#
# Penggunaan dataframe pada Python dengan menggunakan syntaks: df.

# %% [markdown]
# #4. Telaah Data

# %% [markdown]
# Pada telaah data, dapat dilakukan untuk mengetahui:
# - tipe data dari setiap kolom
# - deskripsi statistik data

# %%
#Tampilkan tipe data dari kolom yang ada pada dataset
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# #5. Tipe Data dari kolom yang ada di dataset

# %%
#Kolom  "Id" memiliki tipe data = int
print(df["Id"].dtypes)
#Kolom "SepalLengthCm" memiliki tipe data = float
print(df["SepalLengthCm"].dtypes)
#Kolom "Species" memiliki tipe data = object
print(df["Species"].dtypes)
# Out:
# int64
# float64
# object

# %% [markdown]
# #6. Menghitung ukuran dari dataset

# %%
#Hitunglah ukuran (jumlah baris dan kolom) dari dataset. Dengan menggunakan method function
#Fucntion Shape digunakan untuk mengetahui dimensi dari dataframe atau ukuran baris dan kolomnya.
df.shape
# Out:
# (150, 6)

# %% [markdown]
# #7. Jumlah baris, dan jumlah kolom pada dataset

# %% [markdown]
# Diketahui:
#
# Jumlah Baris pada dataset adalah =  150
#
# Jumlah kolom pada dataset adalah =  6

# %% [markdown]
# #8. Tampilkan data yang hanya berisi kolom "Id" dan kolom "Species" dalam bentuk dataframe.

# %%
df_selected = df[["Id","Species"]]
pd.DataFrame(df_selected)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# #9. Tampilkan data dengan dataframe, dan data yang ditampilkan adalah data pada baris dengan indeks 0 (nol) sampai dengan indeks 9 (sembilan)

# %%
df.iloc[:10]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# #10. Tampilkan data hanya kolom "Id" dan kolom "Species" dengan dataframe, dan yang ditampilkan adalah data pada baris dengan indeks 11 (sebelas) sampai dengan indeks 15 (limabelas)

# %%
#Tampilkan data hanya kolom "Id" dan kolom "Species", pada baris dengan indeks 0 (nol) sampai dengan indeks 9 (sembilan)
df_selected = df[["Id","Species"]]
df_selected.iloc[0:9]
# Out:
#    Id      Species
# 0   1  Iris-setosa
# 1   2  Iris-setosa
# 2   3  Iris-setosa
# 3   4  Iris-setosa
# 4   5  Iris-setosa
# 5   6  Iris-setosa
# 6   7  Iris-setosa
# 7   8  Iris-setosa
# 8   9  Iris-setosa

# %% [markdown]
# #11. DataFrame dapat menampilkan beberapa baris pertama/terakhir dari dataset yang di load. Gunakan Method head() dan tail().

# %% [markdown]
# Latihan: Tampilkan data pada 8 (delapan) baris pertama dari dataset, dengan dataframe.

# %%
df.head(8)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa

# %% [markdown]
# #12. Menampilkan data pada 3 (tiga) baris terakhir dari dataset, dengan dataframe.

# %% [markdown]
# Tampilkan data pada 3 (tiga) baris terakhir dari dataset, dengan dataframe.

# %%
df.tail(3)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# #13. Deskripsi Statistik Data

# %% [markdown]
# DataFrame method describe() menampilkan statistik dasar setiap kolom data yang bertipe numerik, mencakup banyaknya data (count), rerata aritmetik (mean), simpangan baku (std), nilai terkecil (min), kuartil pertama (25%), kuartil kedua/median (50%), kuartil ketiga (75%), dan nilai terbesar (max).

# %% [markdown]
# Hitung korelasi dari dataset. Dengan menggunakan method function

# %%
#df.drop('Id',axis=1,inplace=True)
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# #14. Berdasarkan pada perhitungan korelasi di nomor (11), apakah yang dapat Bapak/Ibu simpulkan sementara? Silakan tuliskan simpulan sementara Bapak/Ibu pada cell di bawah ini.

# %% [markdown]
# Menurut hasil fungsi corr korelasi PetalLengthCm dan PetalWidthCm memiliki korelasi yang tinggi yang dibuktikan dengan nilai 0,96.
# Begitu pula untuk PetalWidthCm dan SepalLengthCm memiliki korelasi yang baik dengan nilai 0,82.
# Dan untuk PetalLenghtCm dan SepalLenghtCm memiliki korelasi yang baik dengan nilai 0.87
# Untuk Attribut lainnya kurang memiliki korelasi yang baik.

# %% [markdown]
# #15. Mengitung korelasi untuk kolom berikut ini: PetalLengthCm, PetalWidthCm

# %%
df_selected2 = df[["PetalLengthCm", "PetalWidthCm"]]
df_selected2.corr()
# Out:
#                PetalLengthCm  PetalWidthCm
# PetalLengthCm       1.000000      0.962757
# PetalWidthCm        0.962757      1.000000

# %% [markdown]
# #16. Method "describe" secara otomatis melakukan komputasi statistik untuk semua continous variable. Secara default "describe" melakukan ignore terhadap variabel bertype objek.

# %% [markdown]
# Komputasi statistik yang dilakukan terdiri dari: count, mean, std, min, max, 25%, 75%, max.
#
# Latihan: Gunakan method describe pada dataset yang sudah di load untuk semua continous variabel. (Dataset Iris.csv)

# %%
#Metode describe untuk komputasi statistik
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# #17. Gunakan method describe pada dataset yang sudah di load untuk data bertype objek. (Dataset Iris.csv)

# %%
df.describe(include = "object")
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %% [markdown]
# #18. Gunakan method describe pada dataset yang sudah di load untuk semua type data (continous variabel dan type object).

# %%
df.describe(include = "all")
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %% [markdown]
# #19. Menghitunglah nilai mean dari dataset.

# %%
df.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %% [markdown]
# #20. Menghitung nilai mean dari dataset untuk kolom PetalLengthCm.

# %%
print("Nilai Mean dari kolom PetalLengthCm: ", df["PetalLengthCm"].mean())
# Out:
# Nilai Mean dari kolom PetalLengthCm:  3.758666666666666

# %% [markdown]
# #21. Carilah nilai minimal dari dataset untuk kolom SepalWidthCm.

# %%
print(df["SepalWidthCm"].min())
# Out:
# 2.0

# %% [markdown]
# #22. Method Groupby

# %% [markdown]
# Method groupby memungkinkan analisis dilakukan secara per kelompok nilai atribut tertentu.

# %% [markdown]
# Hitunglah nilai mean dari dataset untuk kolom SepalLengthCm per Species dengan menggunakan metode groupby.

# %%
df.groupby("Species")["SepalLengthCm"].mean()
# Out:
# Species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: SepalLengthCm, dtype: float64

# %% [markdown]
# #23. Method Value Count

# %% [markdown]
# value_counts() menghasilkan frekuensi setiap nilai unik di dalam kolom, dan yang tertinggi count-nya adalah merupakan modus pada kolom tersebut.

# %% [markdown]
# Hitunglah frekuensi pada kolom 'Species' dengan menggunakan metode value_counts().

# %%
df["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# #24. Menampilkan perhitungan frekuensi pada kolom 'Species' dengan menggunakan metode value_counts() dalam bentuk dataframe.

# %%
valueSpecies = df["Species"].value_counts()
result = pd.DataFrame(valueSpecies)
result
# Out:
#                  Species
# Iris-setosa           50
# Iris-versicolor       50
# Iris-virginica        50

# %% [markdown]
# #25. Menitunglah frekuensi pada kolom 'PetalLenghCm' dengan menggunakan metode value_counts() dan dalam bentuk dataframe.

# %%
valuePetalLenghCm = df["PetalLengthCm"].value_counts()
result = pd.DataFrame(valuePetalLenghCm)
result
# Out:
#      PetalLengthCm
# 1.5             14
# 1.4             12
# 5.1              8
# 4.5              8
# 1.6              7
# 1.3              7
# 5.6              6
# 4.7              5
# 4.9              5
# 4.0              5
# 4.2              4
# 5.0              4
# 4.4              4
# 4.8              4
# 1.7              4
# 3.9              3
# 4.6              3
# 5.7              3
# 4.1              3
# 5.5              3
# 6.1              3
# 5.8              3
# 3.3              2
# 5.4              2
# 6.7              2
# 5.3              2
# 5.9              2
# 6.0              2
# 1.2              2
# 4.3              2
# 1.9              2
# 3.5              2
# 5.2              2
# 3.0              1
# 1.1              1
# 3.7              1
# 3.8              1
# 6.6              1
# 6.3              1
# 1.0              1
# 6.9              1
# 3.6              1
# 6.4              1
